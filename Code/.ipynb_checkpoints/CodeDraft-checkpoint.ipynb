# %% [markdown]
# ### General Notes
# **Understanding CarDD Dataset Tasks and Terminology**
#
# The CarDD dataset paper defines several computer vision tasks used for car damage assessment. Below is a clear explanation of each task and related terms, written for clarity and beginner accessibility.
#
# ---
#
# **Segmentation (Specifically, Instance Segmentation)**
#
# - **What it is**: Segmentation means identifying the exact shape and location of an object (like a scratch or dent) in an image, pixel by pixel.
# - **Instance segmentation**: Not only identifies the shape of the damage, but also separates each **individual instance** of a damage type.
#   - For example, if an image has two dents and one scratch, it marks and separates all three uniquely.
# - **In CarDD**: Each damage is outlined with a polygon, and each is given a unique ID. This allows for fine-grained understanding of the shape and position of each damage.
#
# ---
#
# **Object Detection**
#
# - **What it is**: Identifies the general location of objects using rectangular bounding boxes, and assigns a label (e.g., dent, scratch).
# - **In CarDD**: Used to detect the location of damages, but does not provide pixel-level accuracy like segmentation.
#
# ---
#
# **Classification**
#
# - **What it is**: Predicts the type of object (in this case, type of damage) present in the image.
# - **In CarDD**: Classifies an image into categories like dent, scratch, crack, etc.
#   - It does **not** provide location or shape information, only type.
#
# ---
#
# **Salient Object Detection (SOD)**
#
# - **What it is**: Highlights the most important or visually noticeable objects in an image.
# - **In CarDD**: SOD is used to locate damaged regions **without needing to classify** them into specific types.
#   - Useful for complex shapes or when category is less important than location or severity.
#
# ---
#
# **Other Important Terms**
#
# - **Bounding Box**: A rectangle drawn around an object; used in object detection.
# - **Mask**: A pixel-level binary map of an object; used in segmentation.
# - **COCO Format**: A standardized JSON format for annotations used in many vision datasets.
# - **Instance**: One occurrence of an object or damage (e.g., one dent).
# - **Ground Truth**: Human-provided labels or annotations used as the correct answer for model training and evaluation.
# - **AP / AP50 / AP75**: Evaluation metrics for object detection and segmentation. These represent how well the model predicted object locations. Higher is better.
#   - **AP50**: Accuracy at 50% overlap between predicted and actual boxes/masks.
# - **DCN+**: A deep learning model introduced in the paper that improves performance on challenging damage types.
# - **Focal Loss**: A special loss function that helps the model focus on hard-to-classify or rare cases.
# - **Multi-Scale Learning**: A technique where training images are resized to multiple scales to improve model robustness.
#
# ---
#
# **Summary of Tasks in CarDD**
#
# - **Classification**
#   - Goal: Predict the type of damage in the image (e.g., dent, scratch)
#   - Output: One or more class labels
#   - No location or shape provided
#
# - **Object Detection**
#   - Goal: Find and label the general location of each damage
#   - Output: Bounding boxes with class labels
#   - Good for fast but coarse detection
#
# - **Instance Segmentation**
#   - Goal: Precisely outline each damage region and assign a label
#   - Output: Pixel-level masks + class labels
#   - Most detailed and accurate
#
# - **Salient Object Detection (SOD)**
#   - Goal: Highlight damaged areas without classifying them
#   - Output: Binary saliency maps
#   - Great for irregular or hard-to-label damage

# %% [markdown]
# ### Data Loading

# %% [markdown]
# **Why the CarDD dataset?**
# - Tracks tons of valuable properties about cars/car damages...
#     - Damage types: dent, scratch, crack, glass shatter, tire
#     flat, and lamp broken.
#     - Data volume: it contains 4,000 car damage images with
#     over 9,000 labeled instances which is the largest public
#     dataset of its kind to our best knowledge.
#     - High-resolution: the image quality in CarDD is far
#     greater than that of existing datasets. The average resolution of CarDD is 684,231 pixels (13.6 times higher)
#     compared to 50,334 pixels of the GitHub dataset [14].
#     - Multiple tasks: our dataset comprises four tasks: classification, object detection, instance segmentation, and
#     salient object detection (SOD).
#     - Fine-grained: different from general-purpose object detection and segmentation tasks, the difference between
#     car damage types like dent and scratch is subtle.
#     - Diversity: images of our dataset are more diverse regarding object scales and shapes than the general objects due
#     to the nature of the car damage.
#
# **Why the CarDD_COCO dataset?**
# - Bounding boxes
# - Coordinates
# - ....

# %%
# Load datasets
import pandas as pd 
import os
import json

# Function for loading in images
def create_image_df(directory):
    files = [f for f in os.listdir(directory) if f.lower().endswith('.jpg')]
    return pd.DataFrame({
        'filename': files,
        'filepath': [os.path.join(directory, f) for f in files]
    })

# Function for loading in annotation jsons - can't just read in using pd.read_json - must extract each nested dictionary one by one 
def load_coco_annotations(json_path, datasetname):
    with open(json_path, 'r') as f:
        coco = json.load(f)

    # Extract each part of json and convert to pandas df
    return {
        f'df_{datasetname}_images': pd.DataFrame(coco.get('images', [])),
        f'df_{datasetname}_annotations': pd.DataFrame(coco.get('annotations', [])),
        f'df_{datasetname}_categories': pd.DataFrame(coco.get('categories', [])),
    }
    
# paths for annotations folders
train_annotations_path = 'C:/Users/Sean Salvador/Documents/DS340/Project/Datasets/CarDDdata/data/CarDD_release/CarDD_COCO/annotations/instances_train2017.json'
val_annotations_path = 'C:/Users/Sean Salvador/Documents/DS340/Project/Datasets/CarDDdata/data/CarDD_release/CarDD_COCO/annotations/instances_val2017.json'
test_annotations_path = 'C:/Users/Sean Salvador/Documents/DS340/Project/Datasets/CarDDdata/data/CarDD_release/CarDD_COCO/annotations/instances_val2017.json'
image_info_path = 'C:/Users/Sean Salvador/Documents/DS340/Project/Datasets/CarDDdata/data/CarDD_release/CarDD_COCO/annotations/image_info.xlsx'

# paths for image folders
train_path = 'C:/Users/Sean Salvador/Documents/DS340/Project/Datasets/CarDDdata/data/CarDD_release/CarDD_COCO/train2017'
val_path = 'C:/Users/Sean Salvador/Documents/DS340/Project/Datasets/CarDDdata/data/CarDD_release/CarDD_COCO/val2017'
test_path = 'C:/Users/Sean Salvador/Documents/DS340/Project/Datasets/CarDDdata/data/CarDD_release/CarDD_COCO/test2017'

# Load image info spreadsheet
df_image_info = pd.read_excel(image_info_path)

# Load annotation jsons 
train_dfs = load_coco_annotations(train_annotations_path, "train")
val_dfs = load_coco_annotations(val_annotations_path, "val")
test_dfs = load_coco_annotations(test_annotations_path, "test")

# Load images for viewing 
train_images = create_image_df(train_path)
val_images = create_image_df(val_path)
test_images = create_image_df(test_path)

# Create the individual DataFrames using their dict keys
df_train_images = train_dfs['df_train_images']
df_train_annotations = train_dfs['df_train_annotations']
df_train_categories = train_dfs['df_train_categories']
df_val_images = val_dfs['df_val_images']
df_val_annotations = val_dfs['df_val_annotations']
df_val_categories = val_dfs['df_val_categories']
df_test_images = test_dfs['df_test_images']
df_test_annotations = test_dfs['df_test_annotations']
df_test_categories = test_dfs['df_test_categories']

# %%
# Quick Data Integrity check - check for nulls across all datasets 
# List of all DataFrames with labels for clarity
datasets = {
    "df_image_info": df_image_info,
    "df_train_images": df_train_images,
    "df_train_annotations": df_train_annotations,
    "df_train_categories": df_train_categories,
    "df_val_images": df_val_images,
    "df_val_annotations": df_val_annotations,
    "df_val_categories": df_val_categories,
    "df_test_images": df_test_images,
    "df_test_annotations": df_test_annotations,
    "df_test_categories": df_test_categories,
    "train_images": train_images,
    "val_images": val_images,
    "test_images": test_images,
}

# Loop through and print info for each DataFrame
for name, df in datasets.items():
    print(f"\n=== {name}.info() ===")
    df.info()
# Out:
# === df_image_info.info() ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    4000 non-null   int64
#  1   file_name             4000 non-null   object
#  2   width                 4000 non-null   int64
#  3   height                4000 non-null   int64
#  4   file_size (KB)        4000 non-null   int64
#  5   #instances            4000 non-null   int64
#  6   #categories           4000 non-null   int64
#  7   shooting angle        3560 non-null   object
#  8   complete or partial   4000 non-null   object
#  9   color                 3656 non-null   object
# dtypes: int64(6), object(4)
# memory usage: 312.6+ KB
#
# === df_train_images.info() ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2816 entries, 0 to 2815
# Data columns (total 5 columns):
# ...

# %% [markdown]
# ### Initial Data Viewing
# - Figure out what each dataset contains.

# %%
# Examine image training dataset
print(f"There are {len(train_images)} images in the training dataset")
train_images.head()
# Out:
# There are 2816 images in the training dataset
#      filename                                           filepath
# 0  000001.jpg  C:/Users/Sean Salvador/Documents/DS340/Project...
# 1  000002.jpg  C:/Users/Sean Salvador/Documents/DS340/Project...
# 2  000003.jpg  C:/Users/Sean Salvador/Documents/DS340/Project...
# 3  000004.jpg  C:/Users/Sean Salvador/Documents/DS340/Project...
# 4  000005.jpg  C:/Users/Sean Salvador/Documents/DS340/Project...

# %%
# Examine image info dataset for high level info
    # instances = each damage region 
    # categories = how many different types of damage 
print(f"There are {np.sum(df_image_info['#instances'])} different damages across all datasets." )
print(f"There are {len(df_image_info)} damaged cars across all datasets.")
df_image_info.info()
# Out:
# There are 8740 different damages across all datasets.
# There are 4000 damaged cars across all datasets.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    4000 non-null   int64
#  1   file_name             4000 non-null   object
#  2   width                 4000 non-null   int64
#  3   height                4000 non-null   int64
#  4   file_size (KB)        4000 non-null   int64
#  5   #instances            4000 non-null   int64
#  6   #categories           4000 non-null   int64
#  7   shooting angle        3560 non-null   object
#  8   complete or partial   4000 non-null   object
#  9   color                 3656 non-null   object
# dtypes: int64(6), object(4)
# memory usage: 312.6+ KB

# %%
# View first image/row in train dataset
from PIL import Image
img_path = train_images.loc[0, 'filepath']
img = Image.open(img_path)
# Downsize image a little bit - Scale down by 50%
scale_factor = 0.3
new_size = (int(img.width * scale_factor), int(img.height * scale_factor))
img_scaled = img.resize(new_size)
display(img_scaled)
# Out:
# <PIL.Image.Image image mode=RGB size=300x225>

# %%
# View the annotations training dataset 
df_train_annotations.head(5)
# Out:
#    id  image_id  category_id  \
# 0   1         1            2
# 1   2         1            6
# 2   3         2            6
# 3   4         3            6
# 4   5         4            6
#
#                                         segmentation      area  \
# 0  [[233.35, 46.65, 217.25, 58.24, 210.82, 65.97,...   13584.0
# 1  [[348.93, 137.7, 336.68, 141.53, 323.67, 146.1...  298742.0
# 2  [[625.2, 252.5, 614.49, 257.86, 602.24, 265.51...  114126.0
# 3  [[410.15, 0.71, 405.56, 11.43, 403.27, 22.91, ...  299792.0
# 4  [[325.2, 25.2, 314.49, 32.09, 305.31, 39.74, 2...  383763.0
#
#                                bbox  iscrowd           attributes
# 0   [167.04, 40.21, 202.79, 131.34]        0  {'occluded': False}
# 1  [160.66, 112.45, 684.19, 551.02]        0  {'occluded': False}
# 2   [476.73, 241.02, 397.2, 346.68]        0  {'occluded': False}
# 3     [354.29, 0.0, 645.71, 521.12]        0  {'occluded': False}
# 4     [129.29, 0.0, 718.62, 649.69]        0  {'occluded': False}

# %%
# Info on annotations - note that there are m
df_train_annotations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6211 entries, 0 to 6210
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            6211 non-null   int64
#  1   image_id      6211 non-null   int64
#  2   category_id   6211 non-null   int64
#  3   segmentation  6211 non-null   object
#  4   area          6211 non-null   float64
#  5   bbox          6211 non-null   object
#  6   iscrowd       6211 non-null   int64
#  7   attributes    6211 non-null   object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 388.3+ KB

# %%
# Look at segementation data and bounding boxes for first car in training data
# Note that image id correspond to which car it is 
ex_segs = df_train_annotations['segmentation']
ex_bbox = df_train_annotations['bbox'][0]

# %%
# Let's define some functions to overlay segmentation data, and the bounding boxes onto the image\
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
import numpy as np

def overlay_segmentation(image, seg_data, scale):
    return 

def over_bounding_box(image, bbox_data, scale):
    return

# %%
# Overlay segmentation data: 
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
from PIL import Image
import numpy as np

# Load and scale the image
img_path = train_images.loc[0, 'filepath']
img = Image.open(img_path)
scale_factor = 0.3
new_size = (int(img.width * scale_factor), int(img.height * scale_factor))
img_scaled = img.resize(new_size)

# Load segmentation and scale coordinates
seg = df_train_annotations['segmentation'][0]  # list of one polygon
seg_coords = np.array(seg).reshape(-1, 2) * scale_factor  # Scale all (x, y) pairs

# Plot the image and overlay the polygon
fig, ax = plt.subplots(figsize=(8, 8))
ax.imshow(img_scaled)
polygon = Polygon(seg_coords, closed=True, edgecolor='red', facecolor='none', linewidth=2)
ax.add_patch(polygon)
ax.set_title("Segmentation Overlay")
ax.axis('off')
plt.show()
